# %%
import tensorflow as tf
# import pandas as pd
# import seaborn as sns

# %%
import os
print("Current working Directory:",os.getcwd())
# Out:
# Current working Directory: c:\Users\hp\OneDrive\Documents\AICW\LEAF_DISEASE_DETECTION

# %%
current_directory = os.getcwd()
train_path=os.path.join(current_directory,"dataset","training")
valid_path=os.path.join(current_directory,"dataset","validation")
test_path=os.path.join(current_directory,"dataset","testing")

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    train_path,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    interpolation="bilinear",
   
)
# Out:
# Found 3251 files belonging to 3 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    valid_path,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    interpolation="bilinear",
   
)
# Out:
# Found 416 files belonging to 3 classes.

# %%
testing_set = tf.keras.utils.image_dataset_from_directory(
    test_path,
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    interpolation="bilinear",
   
)
# Out:
# Found 405 files belonging to 3 classes.

# %%
cnn = tf.keras.models.Sequential()

cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',input_shape=[128,128,3]))
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

cnn.add(tf.keras.layers.Dropout(0.25))

cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(units=1500,activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.4))

cnn.add(tf.keras.layers.Dense(units=3,activation='softmax'))

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
training_history=cnn.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.5697 - loss: 0.9332 - val_accuracy: 0.6587 - val_loss: 0.7427
# Epoch 2/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.7336 - loss: 0.6720 - val_accuracy: 0.8389 - val_loss: 0.3998
# Epoch 3/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.8382 - loss: 0.4304 - val_accuracy: 0.8966 - val_loss: 0.3104
# Epoch 4/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.8843 - loss: 0.3286 - val_accuracy: 0.9135 - val_loss: 0.2368
# Epoch 5/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 176s 2s/step - accuracy: 0.9133 - loss: 0.2425 - val_accuracy: 0.8798 - val_loss: 0.2631
# Epoch 6/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9296 - loss: 0.1950 - val_accuracy: 0.9351 - val_loss: 0.1624
# Epoch 7/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9379 - loss: 0.1775 - val_accuracy: 0.8846 - val_loss: 0.2647
# Epoch 8/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9566 - loss: 0.1192 - val_accuracy: 0.9423 - val_loss: 0.1455
# Epoch 9/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9612 - loss: 0.1256 - val_accuracy: 0.9519 - val_loss: 0.1334
# Epoch 10/10
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9711 - loss: 0.0904 - val_accuracy: 0.9327 - val_loss: 0.2085

# %%
train_loss,train_acc=cnn.evaluate(training_set)
print('training accuracy:',train_acc)
# Out:
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 38s 370ms/step - accuracy: 0.9748 - loss: 0.0702
# training accuracy: 0.9747769832611084

# %%
val_loss,val_acc=cnn.evaluate(validation_set)
print('Validation accuracy:',val_acc)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 366ms/step - accuracy: 0.9327 - loss: 0.2085
# Validation accuracy: 0.932692289352417

# %%
cnn.save('trained_plant_disease_model.keras')
